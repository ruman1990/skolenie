# %%
r = range(5)

for i in r:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print('ahoj este raz')
# Out:
# ahoj este raz

# %%
import matplotlib.pyplot as plt
import numpy as np

# Graf 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x, y)

# Graf 2
y2 = np.array([1000, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x, y2)

plt.show()

# %%
plt.scatter(x,y2)
plt.show()

# %%
plt.bar(x,y2)
plt.xlabel('Hodnoty')
plt.ylabel('Y hodnoty')
plt.title('Super graf')
plt.show()

# %%
print('hotovo')
# Out:
# hotovo

# %%
print('ahoj')
# Out:
# ahoj

# %%
plt.pie(y2, labels=x, autopct='%1.1f%%')
plt.title('Kolačový graf')
plt.show()
